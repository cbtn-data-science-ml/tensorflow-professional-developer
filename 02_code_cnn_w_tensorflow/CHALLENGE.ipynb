# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# tf.random.set_seed(42)
# np.random.seed(42)
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# %%
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
num_rows = 2
num_cols = 4
num_images = num_rows * num_cols

# %%
random_indices = np.random.choice(len(train_images), num_images, replace=False)

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6))

for j in range(num_images):
    idx = random_indices[j] 
    ax = axes[j // num_cols, j % num_cols]
    ax.imshow(train_images[idx], cmap='gray')
plt.tight_layout()

# %% [markdown]
# # Improve Baselilne Model

# %%
# implement custom callback
# define model
# add convolutions w 64 filters and 3,3
# add max pooling(2, 2) with relu twice
# flatten()
# add 128 neurons to Dense layer
# output layer 10 (one for each of the 10 classes)
