# %% [markdown]
# # Review:
# ## Single-Layer LSTM

# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Define model parameters
EMBEDDING_OUTPUT_DIM = 64
MAX_LEN = 25
LSTM_UNITS = 16

# Build single-layer LSTM model
model = Sequential([
    Embedding(input_dim=1000, output_dim=EMBEDDING_OUTPUT_DIM),
    LSTM(LSTM_UNITS),
    Dense(1, activation='sigmoid')
], name="Single_LSTM_Model")

# Display the model summary
model.summary()
# Out:
# Model: "Single_LSTM_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Bidirectional LSTM
# This example demonstrates setting up a bidirectional LSTM layer using TensorFlow and Keras, processing inputs in both forward and reverse directions and combining the outputs.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense

# Define parameters
EMBEDDING_OUTPUT_DIM = 64  # Embedding dimensions
MAX_LEN = 25  # Maximum length of input sequence
LSTM_UNITS = 16  # Number of units in each LSTM direction
VOCAB_SIZE = 1000  # Size of vocabulary (e.g., 1000 unique words)

# Define a bidirectional LSTM model
model = Sequential([
    Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_OUTPUT_DIM),
    Bidirectional(LSTM(LSTM_UNITS, return_sequences=True)),  # Bidirectional LSTM layer
    Dense(1, activation='sigmoid')
])

# Print model summary to understand the architecture
model.summary()

# %% [markdown]
# ## Single-Layer GRU
# This example demonstrates setting up a single-layer GRU in TensorFlow and Keras, which processes the sequence data in the forward direction.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

# Define parameters
EMBEDDING_OUTPUT_DIM = 64  # Embedding dimensions
MAX_LEN = 25  # Maximum length of input sequence
GRU_UNITS = 16  # Number of units in the GRU layer
VOCAB_SIZE = 1000  # Size of vocabulary (e.g., 1000 unique words)

# Define a single-layer GRU model
model = Sequential([
    Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_OUTPUT_DIM, input_length=MAX_LEN),
    GRU(GRU_UNITS, return_sequences=False),  # Single GRU layer
    Dense(1, activation='sigmoid')
])

# Print model summary to understand the architecture
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Bidirectional GRU
# Here we set up a bidirectional GRU layer, which also processes each input in both directions, combining the outputs.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense

# Define parameters
EMBEDDING_OUTPUT_DIM = 64  # Embedding dimensions
MAX_LEN = 25  # Maximum length of input sequence
GRU_UNITS = 16  # Number of units in each GRU direction
VOCAB_SIZE = 1000  # Size of vocabulary (e.g., 1000 unique words)

# Define a bidirectional GRU model
model = Sequential([
    Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_OUTPUT_DIM, input_length=MAX_LEN),
    Bidirectional(GRU(GRU_UNITS, return_sequences=True)),  # Bidirectional GRU layer
    Dense(1, activation='sigmoid')
])

# Print model summary to understand the architecture
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # DNN Approach

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Embedding, Dense, Flatten
from tensorflow.keras.models import Sequential


# Part 1: Download and Load the Corpus:
# !wget https://www.gutenberg.org/files/1041/1041-0.txt -O tiny_corpus.txt
with open('tiny_corpus.txt', 'r', encoding='utf-8') as file:
  corpus = file.read()

# Define corpus
corpus =  corpus[:10000] # Limit the corpus size to 10,000 characters (50,000 then 100,000)

# Part 2: Initialize and Fit the Text Vectorization Layer
corpus_lines = corpus.split('\n')
text_ds = tf.data.Dataset.from_tensor_slices(corpus_lines).batch(1024)


# Define TextVectorization layer
vectorizer = keras.layers.TextVectorization(output_mode='int', output_sequence_length=None)
vectorizer.adapt(text_ds)

# Convert the entire corpus to a sequence of numbers
sequence = vectorizer(corpus_lines)
input_sequences = []

# Generate n-grams from the numerical representation
for seq in sequence:
  for i in range(1, len(seq)):
    n_gram_sequence = seq[:i +1]
    input_sequences.append(n_gram_sequence.numpy())

# Pad sequences to ensure uniform length
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create X and y from the Padded Sequences
X = input_sequences[:, : -1]
y = tf.keras.utils.to_categorical(input_sequences[:, -1], num_classes=len(vectorizer.get_vocabulary()))

# Part 3: Define and Compile the Model using Sequential API
model = Sequential([
    Embedding(input_dim=len(vectorizer.get_vocabulary()), output_dim=64),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(vectorizer.get_vocabulary()), activation='softmax')
])

# Train the Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X, y, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# --2024-11-15 16:17:37--  https://www.gutenberg.org/files/1041/1041-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100225 (98K) [text/plain]
# Saving to: ‘tiny_corpus.txt’
#
# tiny_corpus.txt     100%[===================>]  97.88K  --.-KB/s    in 0.08s
#
# 2024-11-15 16:17:37 (1.22 MB/s) - ‘tiny_corpus.txt’ saved [100225/100225]
#
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 824ms/step - accuracy: 0.2707 - loss: 6.4882 - val_accuracy: 0.3707 - val_loss: 5.5881
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3875 - loss: 5.0001 - val_accuracy: 0.3707 - val_loss: 5.1578
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3879 - loss: 4.4170 - val_accuracy: 0.3707 - val_loss: 5.0969
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3950 - loss: 4.0328 - val_accuracy: 0.3707 - val_loss: 4.9469
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3999 - loss: 3.7832 - val_accuracy: 0.3747 - val_loss: 4.9278
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4182 - loss: 3.6613 - val_accuracy: 0.3768 - val_loss: 4.9582
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4019 - loss: 3.6168 - val_accuracy: 0.3768 - val_loss: 4.9756
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3924 - loss: 3.6006 - val_accuracy: 0.3747 - val_loss: 5.0943
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4173 - loss: 3.3889 - val_accuracy: 0.3667 - val_loss: 5.1166
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4125 - loss: 3.4124 - val_accuracy: 0.3707 - val_loss: 5.2517

# %%
# Part 4: Plot Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# # Challenge
# Use one of the above model architechtures and also consider using a functional API approach. Here is an example to review:
#
# ### Sequential API

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# Define parameters
EMBEDDING_OUTPUT_DIM = 64  # Embedding dimensions
MAX_LEN = 25  # Maximum length of input sequence
RNN_UNITS = 16  # Number of units in each RNN direction
VOCAB_SIZE = 1000  # Size of vocabulary (e.g., 1000 unique words)

# Define a simple RNN model using the Sequential API
model = Sequential([
    Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_OUTPUT_DIM, input_length=MAX_LEN),
    SimpleRNN(RNN_UNITS, return_sequences=True),  # Simple RNN layer
    Dense(1, activation='sigmoid')
])

# Print model summary to understand the architecture
model.summary()

# %% [markdown]
# ### Functional API

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dense
from tensorflow.keras.models import Model

# Define parameters
EMBEDDING_OUTPUT_DIM = 64  # Embedding dimensions
MAX_LEN = 25  # Maximum length of input sequence
RNN_UNITS = 16  # Number of units in each RNN direction
VOCAB_SIZE = 1000  # Size of vocabulary (e.g., 1000 unique words)

# Define a simple RNN model using the Functional API
inputs = Input(shape=(MAX_LEN,))
x = Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_OUTPUT_DIM)(inputs)
x = SimpleRNN(RNN_UNITS, return_sequences=True)(x)
outputs = Dense(1, activation='sigmoid')(x)

# Create the model
model = Model(inputs=inputs, outputs=outputs, name="Functional_RNN_Model")

# Print model summary to understand the architecture
model.summary()

# %% [markdown]
# # SimpleRNN Approach

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# Part 1: Download and Load the Corpus
# !wget https://www.gutenberg.org/files/1041/1041-0.txt -O tiny_corpus.txt
with open('tiny_corpus.txt', 'r', encoding='utf-8') as file:
    corpus = file.read()

# Use a larger subset of the corpus to improve training
corpus = corpus[:50000]  # Limit the corpus size to 50,000 characters (then 50k)

# Part 2: Initialize and Fit the Text Vectorization Layer
corpus_lines = corpus.split('\n')
text_ds = tf.data.Dataset.from_tensor_slices(corpus_lines).batch(1024)  # Batch to reduce memory usage

# Define TextVectorization layer
vectorizer = keras.layers.TextVectorization(output_mode='int', output_sequence_length=None)
vectorizer.adapt(text_ds)

# Convert the entire corpus to a sequence of numbers
sequence = vectorizer(corpus_lines)
input_sequences = []

# Generate n-grams from the numerical representation
for seq in sequence:
    for i in range(1, len(seq)):
        n_gram_sequence = seq[:i + 1]
        input_sequences.append(n_gram_sequence.numpy())

# Pad sequences to ensure uniform length
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create X and y from the Padded Sequences
X = input_sequences[:, :-1]
y = tf.keras.utils.to_categorical(input_sequences[:, -1], num_classes=len(vectorizer.get_vocabulary()))


# Part 3: Define and Compile the Model using Sequential API


# Train the Model

# %%
# Part 4: Plot Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# # LSTM Approach

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# Part 1: Download and Load the Corpus
# !wget https://www.gutenberg.org/files/1041/1041-0.txt -O tiny_corpus.txt
with open('tiny_corpus.txt', 'r', encoding='utf-8') as file:
    corpus = file.read()

# Use a larger subset of the corpus to improve training
corpus = corpus[:50000]  # Limit the corpus size to 50,000 characters (then 50k)

# Part 2: Initialize and Fit the Text Vectorization Layer
corpus_lines = corpus.split('\n')
text_ds = tf.data.Dataset.from_tensor_slices(corpus_lines).batch(1024)  # Batch to reduce memory usage

# Define TextVectorization layer
vectorizer = keras.layers.TextVectorization(output_mode='int', output_sequence_length=None)
vectorizer.adapt(text_ds)

# Convert the entire corpus to a sequence of numbers
sequence = vectorizer(corpus_lines)
input_sequences = []

# Generate n-grams from the numerical representation
for seq in sequence:
    for i in range(1, len(seq)):
        n_gram_sequence = seq[:i + 1]
        input_sequences.append(n_gram_sequence.numpy())

# Pad sequences to ensure uniform length
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create X and y from the Padded Sequences
X = input_sequences[:, :-1]
y = tf.keras.utils.to_categorical(input_sequences[:, -1], num_classes=len(vectorizer.get_vocabulary()))


# Part 3: Define and Compile the Model using Sequential API
def build_model(total_words, max_sequence_len):
  inputs = Input(shape=(max_sequence_len -1,))
  x = Embedding(total_words, 64)(inputs)
  x = BatchNormalization()(x)
  x = LSTM(32)(x)
  x = Dropout(0.6)(x)
  outputs = Dense(total_words, activation='softmax')(x)

  model = Model(inputs, outputs)
  optimizer = Adam(learning_rate=0.00005)
  model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  return model

total_words = len(vectorizer.get_vocabulary())
model = build_model(total_words, max_sequence_len)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the Model
history = model.fit(X, y, epochs=20, batch_size=128, validation_split=0.2, callbacks=[early_stopping], verbose=1)
# Out:
# --2024-11-15 16:56:38--  https://www.gutenberg.org/files/1041/1041-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100225 (98K) [text/plain]
# Saving to: ‘tiny_corpus.txt’
#
# tiny_corpus.txt     100%[===================>]  97.88K  --.-KB/s    in 0.1s
#
# 2024-11-15 16:56:39 (949 KB/s) - ‘tiny_corpus.txt’ saved [100225/100225]
#
# Epoch 1/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.0017 - loss: 7.7154 - val_accuracy: 0.3854 - val_loss: 7.7126
# Epoch 2/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0206 - loss: 7.6842 - val_accuracy: 0.3657 - val_loss: 7.6991
# Epoch 3/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1496 - loss: 7.6258 - val_accuracy: 0.3507 - val_loss: 7.6699
# Epoch 4/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3076 - loss: 7.5279 - val_accuracy: 0.3631 - val_loss: 7.5921
# Epoch 5/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3679 - loss: 7.4054 - val_accuracy: 0.4180 - val_loss: 7.4361
# Epoch 6/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3991 - loss: 7.2605 - val_accuracy: 0.4184 - val_loss: 7.2425
# Epoch 7/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4109 - loss: 7.1099 - val_accuracy: 0.4184 - val_loss: 7.0589
# Epoch 8/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4162 - loss: 6.9502 - val_accuracy: 0.4184 - val_loss: 6.8916
# Epoch 9/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4245 - loss: 6.7781 - val_accuracy: 0.4184 - val_loss: 6.7181
# Epoch 10/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4188 - loss: 6.5936 - val_accuracy: 0.4184 - val_loss: 6.5313
# Epoch 11/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4227 - loss: 6.3804 - val_accuracy: 0.4184 - val_loss: 6.3397
# Epoch 12/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4252 - loss: 6.1690 - val_accuracy: 0.4184 - val_loss: 6.1409
# Epoch 13/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4098 - loss: 5.9859 - val_accuracy: 0.4184 - val_loss: 5.9433
# Epoch 14/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4146 - loss: 5.7865 - val_accuracy: 0.4184 - val_loss: 5.7689
# Epoch 15/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4127 - loss: 5.6070 - val_accuracy: 0.4184 - val_loss: 5.6145
# Epoch 16/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4168 - loss: 5.4280 - val_accuracy: 0.4184 - val_loss: 5.4775
# Epoch 17/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4164 - loss: 5.2923 - val_accuracy: 0.4184 - val_loss: 5.3608
# Epoch 18/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4140 - loss: 5.2376 - val_accuracy: 0.4184 - val_loss: 5.2642
# Epoch 19/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4199 - loss: 5.0943 - val_accuracy: 0.4184 - val_loss: 5.1818
# Epoch 20/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4235 - loss: 4.9928 - val_accuracy: 0.4184 - val_loss: 5.1106

# %%
# Part 4: Plot Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# # Generate Text

# %%
# Part 5: Generate Shakespearean-like Text
def generate_text(model, vectorizer, seed_text, max_sequence_len, next_words=10, temperature=1.0):
    for _ in range(next_words):
        token_list = vectorizer([seed_text])
        token_list = keras.preprocessing.sequence.pad_sequences(token_list, maxlen=max_sequence_len - 1, padding='pre')

        probabilities = model.predict(token_list, verbose=0)[0]
        probabilities = np.log(probabilities + 1e-7) / temperature
        exp_preds = np.exp(probabilities)
        probabilities = exp_preds / np.sum(exp_preds)

        predicted_index = np.random.choice(len(probabilities), p=probabilities)

        if predicted_index != 0:
            output_word = vectorizer.get_vocabulary()[predicted_index]
            seed_text += " " + output_word
    return seed_text

seed_text = "ROMEO:"
print(generate_text(model, vectorizer, seed_text, max_sequence_len=max_sequence_len, next_words=20, temperature=0.8))
# Out:
# ROMEO: live wide these in me civil jewel this day repair make moon due sacred

# %% [markdown]
# # Bidirectional LSTM

# %%
from tensorflow.keras.layers import Bidirectional
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# Part 1: Download and Load the Corpus
# !wget https://www.gutenberg.org/files/1041/1041-0.txt -O tiny_corpus.txt
with open('tiny_corpus.txt', 'r', encoding='utf-8') as file:
    corpus = file.read()

# Use a smaller subset of the corpus to save memory
corpus = corpus[:100000]  # Limit the corpus size to 50,000 characters

# Part 2: Initialize and Fit the Text Vectorization Layer
corpus_lines = corpus.split('\n')
text_ds = tf.data.Dataset.from_tensor_slices(corpus_lines).batch(1024)  # Batch to reduce memory usage

# Define TextVectorization layer
vectorizer = keras.layers.TextVectorization(output_mode='int', output_sequence_length=None)
vectorizer.adapt(text_ds)

# Convert the entire corpus to a sequence of numbers
sequence = vectorizer(corpus_lines)
input_sequences = []

# Generate n-grams from the numerical representation
for seq in sequence:
    for i in range(1, len(seq)):
        n_gram_sequence = seq[:i + 1]
        input_sequences.append(n_gram_sequence.numpy())

# Pad sequences to ensure uniform length
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create X and y from the Padded Sequences
X = input_sequences[:, :-1]
y = tf.keras.utils.to_categorical(input_sequences[:, -1], num_classes=len(vectorizer.get_vocabulary()))


# Part 3: Define and Compile the Model using Functional API
def build_model(total_words, max_sequence_len):
    inputs = Input(shape=(max_sequence_len - 1,))
    x = Embedding(total_words, 64)(inputs)  # Simple embedding layer
    x = BatchNormalization()(x)  # This normalizes the inputs to the layer, so the mean is 0 and the variance is 1.
    x = Bidirectional(LSTM(32))(x)  # Use Bidirectional LSTM
    x = Dropout(0.6)(x)  # Randomly sets 60% of nodes to 0 during training to prevent overfitting and encourage robust pattern learning.
    outputs = Dense(total_words, activation='softmax')(x)  # Output layer

    model = Model(inputs, outputs)
    optimizer = Adam(learning_rate=0.00005)  # Reduced learning rate for more gradual improvements
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

total_words = len(vectorizer.get_vocabulary())
model = build_model(total_words, max_sequence_len)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the Model
history = model.fit(X, y, epochs=30, batch_size=256, validation_split=0.2, callbacks=[early_stopping], verbose=1)  # Added early stopping callback

# Part 4: Plot Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)
# Out:
# --2024-11-15 17:02:48--  https://www.gutenberg.org/files/1041/1041-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100225 (98K) [text/plain]
# Saving to: ‘tiny_corpus.txt’
#
# tiny_corpus.txt     100%[===================>]  97.88K  --.-KB/s    in 0.1s
#
# 2024-11-15 17:02:48 (943 KB/s) - ‘tiny_corpus.txt’ saved [100225/100225]
#
# Epoch 1/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 9.4436e-04 - loss: 8.1286 - val_accuracy: 0.3617 - val_loss: 8.1287
# Epoch 2/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.0537 - loss: 8.0639 - val_accuracy: 0.3577 - val_loss: 8.1029
# Epoch 3/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2484 - loss: 7.8988 - val_accuracy: 0.3607 - val_loss: 8.0195
# Epoch 4/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3890 - loss: 7.6345 - val_accuracy: 0.4030 - val_loss: 7.7973
# Epoch 5/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4154 - loss: 7.3315 - val_accuracy: 0.4033 - val_loss: 7.4436
# Epoch 6/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4154 - loss: 7.0527 - val_accuracy: 0.4033 - val_loss: 7.0819
# Epoch 7/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4235 - loss: 6.7819 - val_accuracy: 0.4033 - val_loss: 6.7660
# Epoch 8/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4218 - loss: 6.5309 - val_accuracy: 0.4033 - val_loss: 6.4955
# Epoch 9/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4184 - loss: 6.2893 - val_accuracy: 0.4033 - val_loss: 6.2603
# Epoch 10/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4178 - loss: 6.0641 - val_accuracy: 0.4033 - val_loss: 6.0494
# Epoch 11/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4254 - loss: 5.8230 - val_accuracy: 0.4033 - val_loss: 5.8474
# Epoch 12/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4193 - loss: 5.6275 - val_accuracy: 0.4033 - val_loss: 5.6471
# Epoch 13/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4148 - loss: 5.4398 - val_accuracy: 0.4033 - val_loss: 5.4545
# Epoch 14/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4180 - loss: 5.2327 - val_accuracy: 0.4033 - val_loss: 5.2942
# Epoch 15/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4096 - loss: 5.1179 - val_accuracy: 0.4033 - val_loss: 5.1696
# Epoch 16/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4260 - loss: 4.9205 - val_accuracy: 0.4033 - val_loss: 5.0765
# Epoch 17/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4181 - loss: 4.8862 - val_accuracy: 0.4033 - val_loss: 5.0026
# Epoch 18/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4181 - loss: 4.7753 - val_accuracy: 0.4033 - val_loss: 4.9399
# Epoch 19/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4108 - loss: 4.7770 - val_accuracy: 0.4033 - val_loss: 4.8858
# Epoch 20/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4226 - loss: 4.6527 - val_accuracy: 0.4033 - val_loss: 4.8384
# Epoch 21/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4187 - loss: 4.6288 - val_accuracy: 0.4033 - val_loss: 4.7960
# Epoch 22/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4124 - loss: 4.6175 - val_accuracy: 0.4033 - val_loss: 4.7586
# Epoch 23/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4199 - loss: 4.5504 - val_accuracy: 0.4033 - val_loss: 4.7243
# Epoch 24/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4238 - loss: 4.4679 - val_accuracy: 0.4033 - val_loss: 4.6926
# Epoch 25/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4136 - loss: 4.4926 - val_accuracy: 0.4033 - val_loss: 4.6667
# Epoch 26/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4162 - loss: 4.4449 - val_accuracy: 0.4033 - val_loss: 4.6390
# Epoch 27/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4164 - loss: 4.4160 - val_accuracy: 0.4033 - val_loss: 4.6174
# Epoch 28/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4212 - loss: 4.3615 - val_accuracy: 0.4033 - val_loss: 4.5971
# Epoch 29/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4175 - loss: 4.3655 - val_accuracy: 0.4033 - val_loss: 4.5767
# Epoch 30/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4207 - loss: 4.3064 - val_accuracy: 0.4033 - val_loss: 4.5602

# %% [markdown]
# # Generate Text

# %%
# Part 5: Generate Shakespearean-like Text
def generate_text(model, vectorizer, seed_text, max_sequence_len, next_words=10, temperature=1.0):
    for _ in range(next_words):
        token_list = vectorizer([seed_text])
        token_list = keras.preprocessing.sequence.pad_sequences(token_list, maxlen=max_sequence_len - 1, padding='pre')

        probabilities = model.predict(token_list, verbose=0)[0]
        probabilities = np.log(probabilities + 1e-7) / temperature
        exp_preds = np.exp(probabilities)
        probabilities = exp_preds / np.sum(exp_preds)

        predicted_index = np.random.choice(len(probabilities), p=probabilities)

        if predicted_index != 0:
            output_word = vectorizer.get_vocabulary()[predicted_index]
            seed_text += " " + output_word
    return seed_text

seed_text = "ROMEO:"
print(generate_text(model, vectorizer, seed_text, max_sequence_len=max_sequence_len, next_words=20, temperature=0.8))
# Out:
# ROMEO: his thee the most force that keen
