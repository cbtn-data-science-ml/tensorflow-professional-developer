# %% [markdown]
# # RNNs, Bidirectional RNNs, Linear Combinations, and LSTMs: A Structured Lesson Plan
#
# Here's the equation:
# \begin{equation}
# \Huge{
# y_t = \alpha \left( W_x x_t + W_y y_{t-1} + b \right)
# }
# \end{equation}

# %% [markdown]
# Imagine this sentence: **"I can't believe my cat learned to play the piano!"**
#
# Each word in the sentence represents an input at a **time step**, which the RNN will processes sequentially. The goal here is for the RNN is to predict the next word based on the previous ones—building context over time.

# %% [markdown]
# ```
# Time step 1 - Word: 'I'
#   Input (x_t): 1
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): 0.881939934220468
#   Output after Sigmoid (y_t): 0.7072240617728807
# --------------------------------------------------
# Time step 2 - Word: 'can't'
#   Input (x_t): 2
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): 1.3916815289842295
#   Output after Sigmoid (y_t): 0.8008605539924317
# --------------------------------------------------
# Time step 3 - Word: 'believe'
#   Input (x_t): 3
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): 1.0965300620584308
#   Output after Sigmoid (y_t): 0.7496093793116207
# --------------------------------------------------
# Time step 4 - Word: 'my'
#   Input (x_t): 4
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): 0.6113175776035703
#   Output after Sigmoid (y_t): 0.6482413007267448
# --------------------------------------------------
# Time step 5 - Word: 'cat'
#   Input (x_t): 5
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): 0.06036264622282195
#   Output after Sigmoid (y_t): 0.515086081135078
# --------------------------------------------------
# Time step 6 - Word: 'learned'
#   Input (x_t): 6
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): -0.5322900810665667
#   Output after Sigmoid (y_t): 0.3699829215505565
# --------------------------------------------------
# Time step 7 - Word: 'to'
#   Input (x_t): 7
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): -1.1406158996617866
#   Output after Sigmoid (y_t): 0.24220729902411983
# --------------------------------------------------
# Time step 8 - Word: 'play'
#   Input (x_t): 8
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): -1.726211768945331
#   Output after Sigmoid (y_t): 0.15107277767332566
# --------------------------------------------------
# Time step 9 - Word: 'the'
#   Input (x_t): 9
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): -2.2637425052757925
#   Output after Sigmoid (y_t): 0.09417063854463792
# --------------------------------------------------
# Time step 10 - Word: 'piano!'
#   Input (x_t): 10
#   Bias (b): 1.299922055886111
#   Linear Combination (W_x * x_t + W_y * y_{t-1} + b): -2.7563678225545987
#   Output after Sigmoid (y_t): 0.05972802529373145
# --------------------------------------------------
# ```

# %% [markdown]
# ![Unknown-3.png](data:image/png;base64,...)

# %% [markdown]
# ![Unknown-2.png](data:image/png;base64,...)

# %% [markdown]
# ### Bidirectional RNN Code Example

# %%
# Import libraries


# Define model parameters
# Embedding dimensions of 64
# Maximum length of input sequence should be 25
# Number of units in each RNN direction of 16
# Size of vocabulary of 1000 unique words

# Define a bidirectional RNN model

# Print model summary to understand the architecture

# %% [markdown]
# ## Build a Single-Layer LSTM Model in TensorFlow

# %%
# Import libraries


# Define model parameters


# Build single-layer LSTM model


# Display the model summary
